# %% [markdown]
# # Playing with Nodes
# #### Joshua Hummell

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
G = nx.Graph()

# %%
fig, ax = plt.subplots(figsize=(15,8))

relationships = pd.DataFrame({'from': ['A', 'A', 'A'], 
                              'to':   ['B', 'C', 'D',]})
 
G = nx.from_pandas_edgelist(relationships, 'from', 'to', create_using=nx.Graph())

# Set node_color
nx.draw(G, with_labels=True, node_color='red')

# %%
# Set overall figure size
f = plt.figure(figsize=(20,20))
f.tight_layout()

# Specify data and attributes
relationships = pd.DataFrame({'from': ['Jane', 'Ike', 'Heather', 'Heather', 'Fernando', 'Fernando', 'Fernando', 'Garth', 'Garth', 
                                       'Ed', 'Ed', 'Carol', 'Carol', 'Andre','Beverly','Beverly'], 
                              'to': ['Ike', 'Heather', 'Garth', 'Fernando', 'Garth', 'Carol', 'Diane', 'Diane', 'Ed', 'Diane', 'Beverly', 'Diane', 
                                     'Andre', 'Diane','Diane','Andre']})




nx.draw(G, with_labels=True,node_size = 5000, edgecolors='gray')
plt.title('Spring Layout (Default)', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Spring Layout (Default)')
